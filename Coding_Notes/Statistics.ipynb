# %% [markdown]
# Population vs Sample

# %% [markdown]
# Relative Error: Population mean - Sample mean

# %% [markdown]
# replicate များတာက mean range ပေါ်မှာမထူးဘူး။ shape ကိုတော့ ပိုကိုက်ညီစေတယ်။

# %% [markdown]
# Sampling Distribution ဆိုတာ sample တွေ ဘယ်လိုအနေအထားနဲ့ ဖြန့်ဝေထားသလဲပေါ့
#
# ဥပမာ အံစာတုံးက ၄ လုံးကို လှိမ့်ရင် ရနိုင်တဲ့ distribution က  6 x 6 x 6 x 6 = 1296 ပေါ့
#
# အံစာတုံး အလုံး ၁၀၀ ကို လှိမ့်ရင် ရနိုင်တဲ့ distribution က 6 x 10^100 က universe ထဲက Atom အရေအတွက်နဲ့တူပါသတဲ့
#
# ဒီတော့ distribution အကုန်လုံးကို တွက်ချဖို့ ဆိုတော့ သီအိုရီအရဖြစ်နိုင်ပေမယ့် calculation power အရ မရသေးပါ။ ဒါကြောင့် အထက်က ၁၂၉၆ distribution အစား random အကြိမ် ၁၀၀၀ ကောက်တာက နီးနီးစပ်စပ် distribution ကို ရပါတယ် (mean ရဲ့ historgram ကိုပြောတာပါ)

# %% [markdown]
# Rolling dice က ဂဏန်းတစ်ခုက ပြန်ရနိုင်တာမို့
# **random sampling with replacement or resampling** လို့ခေါ်ပါတယ်
#
# Card Game မှာတော့ Card တစ်ခုက ပေးလိုက်ပြီးဖြစ်တာမို့
# **random sampling without replacement** ပါ။

# %% [markdown]
# ##Bootstrap Distribution##

# %% [markdown]
# Bootstrap က ရှိတဲ့ sample ကို full 100% random ကို with replacement နဲ့ ယူတာပါ replicate အကြိမ်ယူသလောက် နဂို sample ထက်ကြီးလာမှာပါ
#
# Data တွေ အကုန်မကောက်နိုင်တဲ့အခါ sample ကနေ population ကို ပြန်သွားရတာပါ
#
# ***Note—*** Bootstrapping cannot correct bias from sampling.
#
# The mean of the bootstrap distribution will always be near the sample mean, which may not necessarily be very close to the population mean.

# %% [markdown]
# #ဒီတော့...#
#
# mean လေးမျိုးရှိတယ်။ pop_mean, sample_mean, sample_distribution_mean, boostrap_distribution_mean တို့ပေါ့။
#
# (distribution ဆိုတာ random ကောက်ပြီး ဖြန့်ဝေထားတာကိုပြောတာ)
#
# အဲဒီ လေးခုမှာ အောက်ပါအတိုင်း ကောက်ချက်ချနိုင်တယ်။
#
# ***The sampling distribution mean is the best estimate of the true population mean; the bootstrap distribution mean is closest to the original sample mean.***

# %% [markdown]
# Checking your understanding

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Standard Error*** is standard deviation of statistics of interest.
#
# `standard_error=np.std(bootstrap_distn,ddof=1)`
#
# Standard error times squre root of sample size estimates the population standard deviation.
#
# `standard_deviation_pop = standard_error*np.sqrt(500)`
#
# True Standard Deviation
#
# `df_pop['flavor'].std(ddof=0)`

# %% [markdown]
# SD လေးခု ရှိမယ်။ pop_sd, sample_sd, sample_distribution_sd, bootstrap_distribution_sd တို့ပါ။
#
# **The calculation from the bootstrap distribution is the best estimate of the
# population standard deviation.**

# %% [markdown]
# #Confidence Interval#
#
# "Values within one standard deviation of the mean" includes a large number of values from each of these distributions.
#
# We'll define a related concept called a **confidence interval** —
# A range of plausible values for an unknown quantity.
#
# CI ဆိုတာ SD 1 ကို တကယ့် value အနေနဲ့ ပြောင်းပြီးသတ်မှတ်တာပေါ့
# ဥပမာ..distribution တစ်ခုခုရဲ့ 2.5 percentile နဲ့ 97.5 percentile အတွင်း ရှာမယ်ဆိုရင်
#
#
# ```
# lower value =np.quantile(distribution,0.025)
#
# upper value =np.quantile(distribution,0.975)
# ```
#
#
#
# ဒါက popoulation တစ်ခုလုံးရဲ့ distribution သိရင်တော့ ဟုတ်တာပေါ့။ လက်တွေ့မှာတော့ နည်းနှစ်နည်း ဖြင့်ရှာနိုင်ပါတယ်။
#
# #ပထမနည်း#
#
# အရင်မြင်ဘူးတဲ့ Normal Distribution က bell curve က
# PDF = Probability Density Function လို့လဲခေါ်တယ်။ Calculus ကိုသုံးပြီး derived လုပ်တဲ့အခါ
# CDF = Cumumlative Distribution Function ရမယ်။ အဲဒါက Area under the bell curve.
#
# အဲဒီ CDF ကို x,y axis ချိန်းတဲ့အခါ inv.CDF ဖြစ်ပြီး ဒီလို Curve ရတယ်။

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# scipy library သုံးပြီး တွက်မယ်ဆိုရင် ဒီလိုတွက်နိုင်ပါတယ်။
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# အဲဒီမှာ လိုချင်တဲ့ percentile တခုကို ထည့်ရင် sd value တစ်ခုပြန်ပေးပါမယ်။ sd value ကနေ CI ကို ဆက်တွက်လို့ရသွားပါပြီ။

# %% [markdown]
# #ဒုတိယနည်း# တကယ်က ပထမနည်းက ideal ။ mean 0 , std 1 လို့ ပြတာ။
# mboostrap distribution ကနေ mean တခုရှာ
#
# boostrap distribution ကနေ standard error ကနေ sd တွက်
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #1—The std deviation of a bootstrap statistic is a good approximation of the standard error.#
# #2—Can assume bootstrap distributions are normally distributed for confidence intervals.#

# %% [markdown]
# #Z-scores#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# `z_score = (samp.mean()-hypothesised mean value)/std_error`

# %% [markdown]
# # **p-values**
#
# e.g Criminal Trials
# 1.Two possible true states:
#   1) Defendant commited the crime.
#   2) Defendant did not commit the crime.
#
# 2.Two possible verdicts (decisions/opinions):
#   1) Guilty
#   2) Not Guilty
#
# ---
# adult: 14 and above.
# child: below 14.
# 35% of software developers started programming as children.
# Question: Evidence that a greater proportion of DS starting programming as children?

# %% [markdown]
# A *hypothesis* is a statement about an unknown population parameter.
#
# A *hypothesis test* is a test of two competing hypotheses.
#
# *   The *null hypothesis (H0)* is the existing idea.
# *   The *alternative hypothesis (HA)* is the new "challenger" idea of the researcher.

# %% [markdown]
# For our problem:
#
# H0: The proportion of data scientists starting programming as children is 35%.
#
# HA: The proportion of data scientists starting programming as children is greater than 35%.

# %% [markdown]
# Hypothesis tests check if the sample statistics lie in the tails of the null distribution.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #p-value
#
# ![image.png](data:image/png;base64,...)
#
#
# For two tails, sum both left and right equations.
#
# ```
# from scipy.stats import norm
# 1 - norm.cdf(z_score, loc=0, scale=1)
# ```

# %% [markdown]
# #Statistical significance

# %% [markdown]
# p-values quantify evidence for the null hypothesis
#
# Large p-value → fail to reject null hypothesis
#
# Small p-value → reject null hypothesis
#
# What decide small or large?
# Now,** Statistical Significance** enter.

# %% [markdown]
# #Significance Level#
#
# The significance level of a hypothesis test (α) is the threshold point for "beyond a
# reasonable doubt"
#
# Common valve of alpha are 0.2, 0.1, 0.05, and 0.01.
#
# If p<=alpha, reject H0, else fail to reject H0.
#
# alpha should be set prior to conducting the hypothesis test.

# %% [markdown]
# #Confidence intervals#

# %% [markdown]
# 1-alpha နဲ့ ယူဆထားတယ်

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Performing t-Test#

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Calculating p-value from t-test
#
# #1-t.cdf လား t.cdf လားသေချာစဉ်းစားပါ။ left tail လား right tail လား ကိုကြည့်ပါ။ less ဆိုရင် left tail (t.cdf), greater ဆိုရင် right tail (1-t.cdf) ဖြစ်ပါတယ်။ For two-tailed, summerize both equations.

# %% [markdown]
# #Knowledge Check
#
# ![image.png](data:image/png;base64,...)
# Terrific! Using a sample standard deviation to estimate the standard error is computationally easier than using bootstrapping. However, to correct for the approximation, you need to use a t-distribution when transforming the test statistic to get the p-value.

# %% [markdown]
# #Paired t-test#
#
# When we compare 2008 and 2012 data, we are comparing two independent data. So, we will generate new data colum as difference. So now paired value become one.
#
# That difference is zero means H0.
# Taht difference greater or large means HA.
#
# We call calculate, sample mean, H0 and SD, df, t_stat. Then, we can calculate p value.
#
# To be easier than that, we can use pingouin package.
#
# `import pingouin`
#
#
#
# With pinguin, you can do even less work. No need to make "difference" column. put "pair=True".
# If you set 'pair=False', that is unpaired test and more df and p-value larger. It makes false negative error more.

# %% [markdown]
# ***Paired t-test party! Using .ttest() lets you avoid manual calculation to run your test. When you have paired data, a paired t-test is preferable to the unpaired version because it reduces the chance of a false negative error.***

# %% [markdown]
# ```
# pingouin.ttest(x=sample_dem_data['diff'],
#                               y=0,
#                               alternative="two-sided")
# ```
#
#
#
# ```
# pingouin.ttest(x=sample_dem_data['dem_percent_12'],
#                               y=sample_dem_data['dem_percent_16'],paired=True,
#                               alternative="two-sided")
# ```

# %% [markdown]
# #Knowledge Check#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #ANOVA Test#  (For 3 and more categories)

# %% [markdown]
# #One-sample proportion test#

# %% [markdown]
# #Knowledge Check#
# Zipadeedoodah for z-scores! The t-test is needed for tests of mean(s) since you are estimating two unknown quantities, which leads to more variability.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In above questions,
#
#
# (1) No.There's only one estimate value (p_cap) instead of x and s for t-test problems.
#
# (2)No. The population standard deviation is rarely known, in general, so there's a different reason here.
#
# (3)Yes. The t-test is needed for tests of mean(s) since you are estimating two unknown quantities, which leads to more variability.
#
# (4)No.The sample proportions are considered as a single statistic, not two.

# %% [markdown]
# #Two sample proportion tests#

# %% [markdown]
# Wiht below python package, you can calculate these tests.
#
# ```
# from statsmodels.stats.proportion import proportions_ztest
# z_score, p_value = proportions_ztest(count=n_hobbyists, nobs=n_rows,
#                                      alternative="two-sided")
# ```

# %% [markdown]
# #Chi-square test of independence

# %% [markdown]
# #Knowledge Check
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (1) No. The chi-square distribution is defined only for positive x values
#
# (2) Yes. Like the t-distribution, the chi-square distribution has degrees of freedom and non-centrality parameters. When these numbers are large, the chi-square distribution can be approximated by a normal distribution.
#
# (3)No. For small degrees of freedom and non-centrality, the chi-square distribution looks nothing like a normal distribution.
#
# (4)No. The PDF of the chi-square distribution is right-skewed.

# %% [markdown]
# #Knowledge Check
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (1)No. Left-tails tend to be more important when test statistics are negative, which isn't possible when it is a square number.
#
# (2)Yes.The chi-square test statistic is a square number, so it is always non-negative, so only the right tail tends to be of interest.
#
# (3)No. Two-tails are important when differences between observations and expected values can occur in two directions, which tends to not be the case with chi-square tests.
#
# (4)No. All hypothesis tests consider the tails of distributions.
#
# (5)No. Only one type of tail is considered by chi-square tests.

# %% [markdown]
# #Knowledge Check
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (1)No. The p-value is less than the significance level, so you should reject the null hypothesis.
#
# (2)No. The null hypothesis states that the variables are independent.
#
# (3)No. The p-value is less than the significance level, so you should reject the null hypothesis.
#
# (4)Yes. Independence insight! The test to compare proportions of successes in a categorical variable across groups of another categorical variable is called a chi-square test of independence.

# %% [markdown]
# #Chi-square Goodness of fit tests

# %% [markdown]
# A little understand.
# Hypothesised distribution to be checked with sample distribution.
# Then, chi-square check p-value. If larged, accept H0.

# %% [markdown]
# #Assumptions in hypothesis testing#
#
# *Only when these below assumptions are met, hypothesis testing shall be used.*
#
# ***Randomness***
#
# **1)Assumption—**
# The samples are random subsets of larger populations.
#
# **2)Consequence—**
# Random sample only can be representative from the population.
#
# **3)How to check this—**
# Understand how your data was collected.
# \
# \
# ***Independence of observations***
#
# **1)Assumption—**
# Each observation(row) in the dataset is independent.
#
# **2)Consequence—**
# Increased changce of false negative/positive error.
#
# **3)How to check this—**
# Understand how your data was collected.
# \
# \
# ***Large sample size***
#
# **1)Assumption—**
# The sample is big enough to mitigate uncertianty, so that the Central Limit Theorem applies.
#
# **2)Consequence—**
# Wider confidence intervals
# \
# Increased change cof flase negative/positive errors.
#
# **3)How to check this—**
# It depends on the test.

# %% [markdown]
# #How many samples shall be used at minimum?
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Sanity Check#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Knowledge Check#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Non-Parametric Tests#

# %% [markdown]
# ##Parametric tests##
#
# *  z-test, t-test, and ANOVA are all parametric tests.
# *  Assume normal distributions.
# *  shall be sufficiently large number of samples.
#
# If small qty, let's try with pingouin.ttest().
#
# Suppose we have 5 samples. It will lead to small p values to reject Null Hypothesis.
#
# Now, #Non-parametric test enter.
# * It can avoid parametric assumptions and conditions.
# * It uses ranks of the data. e.g
#     x = [1,15,3,10,6] # ranking by scipy.stats rankdata(x)
#
#
# **Note**
# \
# *Non-parametric tests are more reliable than parametric tests for small sample sizes and when data isn't normally distributed.*
#
#
# **We will use Wilcoxon-signed rank test**
#
# * Developed by Frank Wilcoxon in 1945
# * One of th first non-parametric prodedures

# %% [markdown]
# #Knowledge Check
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (1)No. The Wilcoxon signed-rank test is used for comparing numeric data, whereas the z-test compares categorical data.
#
# (2)No.The Wilcoxon signed-rank test is used for comparing two numeric columns, whereas the goodness of fit test compares the distribution of a categorical column to a hypothesized distribution.
#
# (3)Yes.The Wilcoxon signed-rank test works well when the assumptions of a paired t-test aren't met.
#
# (4)No.The Wilcoxon signed-rank test is used for comparing two linked columns, whereas an ANOVA compares numerical results across two or more groups.

# %% [markdown]
# #Non-parametric ANOVA and unpaired t-tests

# %% [markdown]
# #Knowledge Check
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ace assumption! All hypothesis tests assume that the data are collected at random from the population, that each row is independent of the others, and that the sample size is "big enough".

# %% [markdown]
# Parametric Tests: z-test, t-test, ANOVA (Note: Assuming Normal Distribution and large sample size)
#
# **Note:** t-Test needs min 30 samples.
#
# ```
# alpha = 0.01
# import pingouin
# pingouin.ttest(x=repub_votes_potus_08_12_small['repub_percent_08'],
#                y=repub_votes_potus_08_12_small['repub_percent_12'],
#                paired=True,
#                alternative="less")
# ```
# ![image.png](data:image/png;base64,...)
