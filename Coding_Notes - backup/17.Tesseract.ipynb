# %% [markdown]
# Sometimes, you may see the following error. That is due to the following.
#  *No module named 'pytesseract*
#  **You did install the package, but is is not in your python path.**

# %%
# !pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.7-py2.py3-none-any.whl size=13953 sha256=11d3685a4a337656f020b317fe798ec6b44f6e53bd917a72e27fa55ab50d7e77
#   Stored in directory: /root/.cache/pip/wheels/81/20/7e/1dd0daad1575d5260916bb1e9781246430647adaef4b3ca3b3
# Successfully built pytesseract
# ...

# %%
import pytesseract
dir(pytesseract)
# Out:
# ['ALTONotSupported',
#  'Output',
#  'TSVNotSupported',
#  'TesseractError',
#  'TesseractNotFoundError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'get_languages',
#  'get_tesseract_version',
#  'image_to_alto_xml',
#  'image_to_boxes',
#  'image_to_data',
#  'image_to_osd',
#  'image_to_pdf_or_hocr',
#  'image_to_string',
#  'pytesseract',
#  'run_and_get_output']

# %% [markdown]
# If you want to inspect Source Code

# %%
import inspect
src = inspect.getsource(pytesseract.image_to_string)
print(src)
# Out:
# def image_to_string(
#     image,
#     lang=None,
#     config='',
#     nice=0,
#     output_type=Output.STRING,
#     timeout=0,
# ):
#     """
#     Returns the result of a Tesseract OCR run on the provided image to string
#     """
#     args = [image, 'txt', lang, config, nice, timeout]
#
#     return {
#         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#         Output.STRING: lambda: run_and_get_output(*args),
#     }[output_type]()

# %% [markdown]
# Another way is use two question marks.

# %%
pytesseract.image_to_string??

# %% [markdown]
# Now, if you want to use OCR (means, Image to String), recall image shall be PIL image.

# %%
from PIL import Image

image = Image.open("readonly/text.png")
display(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-b42908b0baa0> in <module>()
#       1 from PIL import Image
#       2
# ----> 3 image = Image.open("readonly/text.png")
#       4 display(image)
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: 'readonly/text.png'

# %%
import pytesseract
text = pytesseract.image_to_string(image)
print(text)
# Out:
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     249     try:
# --> 250         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     251     except OSError as e:
#
# /usr/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# ...
